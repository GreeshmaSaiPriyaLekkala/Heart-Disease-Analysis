# %% [markdown]
# # 1.Import the libraries and dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')

# %% [markdown]
# # 2.Display top 5 rows of the dataset

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# - age
# - sex
# - chest pain type (4 values)
#   - value 0:typical angina
#   - value 1:atypical angina
#   - value 2:non-anginal pain
#   - value 3:asymptomatic
# - tresttbps: resting blood pressure (in mm Hg on admission to the hospital)
# - chol: serum cholesterol in mg/dl
# - fbs:(fasting blood sugar> 120 mg/dl)(1=true,0=false
# - restecg: resting electrocardiographic results
#   - value 0:normal
#   - value 1:having ST-T wave abnormality(T wave inversions and/or ST elevation or depression of>0.05 mV)
#   - value 2:showing probable or definite left ventricular hypertrophy by Estes' criteria
# - thalach: maximum heart rate achieved
# - exang: exercise induced angina(1=yes,0=no)
# - oldpeak: ST depression induced by exercise relative to rest
# - slope: the slope of the peak exercise ST segment
#   - value 1: upsloping
#   - value 2: flat
#   - value 3: downloping
# - ca: number of major vessels (0-3)colored by fluoroscopy
# - thal: 3=normal, 6=fixed defect, 7=reversible defect
# - target: 0=less chance of heart attack, 1=more chance of heart attack
#
#
# # 3.Check the last 5 rows of the dataset

# %%
data.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # 4. Find the shape of our dataset(number of rows and columns)

# %%
data.shape
# Out:
# (1025, 14)

# %% [markdown]
# # 5. Get information about our dataset like total number of rows, columns, datatypes of each column and memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # 6.Check the null values in the dataset

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # 7.Check the duplicate data and drop them.

# %%
data_dup = data.duplicated().any()
print(data_dup)

# if the output is true, there's some duplicates
# Out:
# True

# %%
data = data.drop_duplicates()  

# drop the duplicates

# %%
data.shape
# Out:
# (302, 14)

# %% [markdown]
# # 8.Get overall statistics about the dataset

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # 9.Draw correlation matrix

# %%
# to check correlation between different features available in our dataset

plt.figure(figsize=(13,7))
sns.heatmap(data.corr(), annot=True)

# data.corr()
# sns.heatmap()
# plt.figure(figsize(1y7,6))
# annot=True (parameter of this heatmap method of seaborn)
# Out:
# <Axes: >

# %% [markdown]
# # 10.How many have heart disease, and how many don't have heart disease in this dataset?

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()

#value_counts() returns the count of unique values in a column in descending order
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x=data['target'])

#1-heart disease
# from this count plot it is clear that half of the people have heart disease
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# # 11.Find count of male and female in this dataset

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# use countplot to visualise it

sns.countplot(x = data['sex'])

# change the xlabels[0,1] as ['Female','Male']

plt.xticks([0,1],['Female','Male'])
plt.show()

# %%
# this clunt plot it is clear that, approximately 30% of people are feamle and 70% are male.

# %% [markdown]
# # 12.Find gender distribution according to the target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# use countplot for distribution 

sns.countplot(x='sex',hue='target',data=data)
plt.xticks([0,1],['Female','Male'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 3
#       1 # use countplot for distribution
# ----> 3 sns.countplot(x='sex',hue='target',data=data)
#       4 plt.xticks([0,1],['Female','Male'])
#       5 plt.legend(labels=['No-Disease','Disease'])
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
# from this count plot there are more men for disease and non-disease target

# %% [markdown]
# # 13.Check age distribution in the dataset

# %%
sns.distplot(data['age'],bins=20)
plt.show()
# Out:
# /var/folders/_5/cj46_23n6d7_j_bbrg8wdpr80000gn/T/ipykernel_9394/4281029158.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'],bins=20)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# from this plot we can see that most of the people in this study aged between 50-60

# %% [markdown]
# # 14. Check which chest pain type is more common
# - chest pain type:
#   - value 0:typical angina
#   - value 1:atypical angina
#   - value 2:non-anginal pain
#   - value 3:asymptomatic

# %%
sns.countplot(x=data['cp'])
plt.xticks([0,1,2,3],['typical angina', 'atypical angina', 'non-anginal pain','asymptomatic'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # 15.Show the chest pain distribution as per target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='cp',hue='target',data=data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.countplot(x='cp',hue='target',data=data)
#       2 plt.legend(labels=['No-Disease','Disease'])
#       3 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
# from this graph we can see that healthy people also have chest pain.
# chest pain can be subjective. Due to stress, physical activities tc.
# it varies between gender.

# %% [markdown]
# # 16.Show fasting blood sugar distribution according to target variable

# %%
sns.countplot(x='fbs', hue='target', data=data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# fbs is diabetic indicator
# fbs greater than 120 are diabetics
# higher number of diabetics patient without heart disease
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sns.countplot(x='fbs', hue='target', data=data)
#       2 plt.legend(labels=['No-Disease','Disease'])
#       3 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %% [markdown]
# # 17.Check resting blood pressure distribution

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# create a histogram
data['trestbps'].hist()

# from this histogram we can see that the blood pressure of the people in this study is between 120 and 140
# Out:
# <Axes: >

# %% [markdown]
# # 18.Compare resting blood pressure asper sex column

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# lets use 'facetgrade class'
# facetgrade class is useful when you want to visualize the distribution of variable or the relationship between multiple variables seperately, within subset of your dataset

g = sns.FacetGrid(data,hue='sex',aspect=4)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=["Male","Female"])

# we are using kdeplot of seaborn
# we have to compare resting bp as per sex column. So we have to pass resting blood pressure column, here it is trestbps.
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
# women has lower resting blood pressure compared to men.
# for women os around 120, while for men it is little less than 140.

# %% [markdown]
# # 19.Show distribution of serum cholesterol

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# we are using histogram to check distribution of the column
data['chol'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 20.Plot continuous variables

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# first we have to seperate columns which contain continuous values and which contain categorical values

# %%
# lets create two empty lists
categ_value=[]
cont_value=[]

for column in data.columns:
    if data[column].nunique() <=10:
        categ_value.append(column)
    else:
        cont_value.append(column)

# %%
categ_value
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_value
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(cont_value,figsize=(15,6))
plt.tight_layout()
plt.show()
